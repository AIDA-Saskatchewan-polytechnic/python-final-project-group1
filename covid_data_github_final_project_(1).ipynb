# %%
import pandas as pd
import requests

df_confirm = pd.read_csv ('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
df_death = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')

# %%
#@title Default title text
df_death
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 279            NaN    West Bank and Gaza  31.952200   35.233200        0
# 280            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 281            NaN                 Yemen  15.552727   48.516388        0
# 282            NaN                Zambia -13.133897   27.849332        0
# 283            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/15/22  4/16/22  \
# ...

# %%
sum(df_confirm,df_death)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-5-cd812bc20fdb> in <module>()
# ----> 1 sum(df_confirm,df_death)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py in __add__(self, other)
#      90     @unpack_zerodim_and_defer("__add__")
#      91     def __add__(self, other):
# ---> 92         return self._arith_method(other, operator.add)
#      93
#      94     @unpack_zerodim_and_defer("__radd__")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _arith_method(self, other, op)
#    6864         self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
#    6865
# ...

# %%
df_death
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 279            NaN    West Bank and Gaza  31.952200   35.233200        0
# 280            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 281            NaN                 Yemen  15.552727   48.516388        0
# 282            NaN                Zambia -13.133897   27.849332        0
# 283            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/16/22  4/17/22  \
# ...

# %%
import pandas as pd
import requests

url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=TSLA&datatype=json&apikey=DRDU0ACD89IZ5H2D'
r_stock_price = requests.get(url)
data_stock_price = r_stock_price.json()

print(data_stock_price)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'TSLA', '3. Last Refreshed': '2022-04-25', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2022-04-25': {'1. open': '978.9700', '2. high': '1008.6200', '3. low': '975.3000', '4. close': '998.0200', '5. volume': '22593647'}, '2022-04-22': {'1. open': '1014.9100', '2. high': '1034.8500', '3. low': '994.0001', '4. close': '1005.0500', '5. volume': '23232186'}, '2022-04-21': {'1. open': '1074.7300', '2. high': '1092.2200', '3. low': '996.4150', '4. close': '1008.7800', '5. volume': '35138779'}, '2022-04-20': {'1. open': '1030.0000', '2. high': '1034.0000', '3. low': '975.2501', '4. close': '977.2000', '5. volume': '21616141'}, '2022-04-19': {'1. open': '1005.0600', '2. high': '1034.9400', '3. low': '995.3250', '4. close': '1028.1500', '5. volume': '16615944'}, '2022-04-18': {'1. open': '989.0300', '2. high': '1014.9200', '3. low': '973.4100', '4. close':
# ...

# %%
import pandas as pd
import requests

url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=TD&datatype=json&apikey=DRDU0ACD89IZ5H2D'
r_stock_price = requests.get(url)
data_stock_price = r_stock_price.json()

print(data_stock_price)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'TD', '3. Last Refreshed': '2022-04-25', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2022-04-25': {'1. open': '72.7100', '2. high': '73.4200', '3. low': '71.5100', '4. close': '73.1300', '5. volume': '2538138'}, '2022-04-22': {'1. open': '75.0000', '2. high': '75.0000', '3. low': '73.1200', '4. close': '73.3200', '5. volume': '2316120'}, '2022-04-21': {'1. open': '76.5900', '2. high': '77.4500', '3. low': '75.0450', '4. close': '75.2500', '5. volume': '1666796'}, '2022-04-20': {'1. open': '75.7100', '2. high': '76.6600', '3. low': '75.5200', '4. close': '76.1500', '5. volume': '1644099'}, '2022-04-19': {'1. open': '74.4500', '2. high': '75.0000', '3. low': '74.1800', '4. close': '74.8800', '5. volume': '1792038'}, '2022-04-18': {'1. open': '74.3800', '2. high': '74.7750', '3. low': '74.0200', '4. close': '74.2400', '5. volume': '1257389'}, '2022-
# ...

# %%
import pandas as pd
import requests

url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=AC&datatype=json&apikey=DRDU0ACD89IZ5H2D'
r_stock_price = requests.get(url)
data_stock_price = r_stock_price.json()

print(data_stock_price)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'AC', '3. Last Refreshed': '2022-04-25', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2022-04-25': {'1. open': '39.4100', '2. high': '40.2126', '3. low': '38.2000', '4. close': '39.5000', '5. volume': '7149'}, '2022-04-22': {'1. open': '39.9100', '2. high': '40.5050', '3. low': '39.7600', '4. close': '39.7600', '5. volume': '5559'}, '2022-04-21': {'1. open': '39.5000', '2. high': '40.7500', '3. low': '39.5000', '4. close': '39.9000', '5. volume': '8253'}, '2022-04-20': {'1. open': '38.9600', '2. high': '41.0182', '3. low': '38.9600', '4. close': '39.8300', '5. volume': '10025'}, '2022-04-19': {'1. open': '36.9968', '2. high': '39.8600', '3. low': '36.9968', '4. close': '38.9600', '5. volume': '27662'}, '2022-04-18': {'1. open': '38.2000', '2. high': '40.1000', '3. low': '37.8900', '4. close': '38.2000', '5. volume': '22241'}, '2022-04-14': {'1. op
# ...

# %%
import pandas as pd
import requests

url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=REMAX&datatype=json&apikey=DRDU0ACD89IZ5H2D'
r_stock_price = requests.get(url)
data_stock_price = r_stock_price.json()

print(data_stock_price)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'REMAX', '3. Last Refreshed': '2022-04-22', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2022-04-22': {'1. open': '16.3700', '2. high': '16.3700', '3. low': '16.3700', '4. close': '16.3700', '5. volume': '0'}, '2022-04-21': {'1. open': '16.5300', '2. high': '16.5300', '3. low': '16.5300', '4. close': '16.5300', '5. volume': '0'}, '2022-04-20': {'1. open': '16.8000', '2. high': '16.8000', '3. low': '16.8000', '4. close': '16.8000', '5. volume': '0'}, '2022-04-19': {'1. open': '16.9100', '2. high': '16.9100', '3. low': '16.9100', '4. close': '16.9100', '5. volume': '0'}, '2022-04-18': {'1. open': '16.9400', '2. high': '16.9400', '3. low': '16.9400', '4. close': '16.9400', '5. volume': '0'}, '2022-04-14': {'1. open': '17.0200', '2. high': '17.0200', '3. low': '17.0200', '4. close': '17.0200', '5. volume': '0'}, '2022-04-13': {'1. open': '17.1300', '2
# ...

# %%
import pandas as pd
import requests

url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=GOLD&datatype=json&apikey=DRDU0ACD89IZ5H2D'
r_stock_price = requests.get(url)
data_stock_price = r_stock_price.json()

print(data_stock_price)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'GOLD', '3. Last Refreshed': '2022-04-25', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2022-04-25': {'1. open': '22.7000', '2. high': '22.9650', '3. low': '22.2200', '4. close': '22.7300', '5. volume': '32473036'}, '2022-04-22': {'1. open': '23.5300', '2. high': '24.0900', '3. low': '23.4800', '4. close': '23.7300', '5. volume': '22036510'}, '2022-04-21': {'1. open': '24.9200', '2. high': '24.9990', '3. low': '23.8615', '4. close': '24.2200', '5. volume': '26109732'}, '2022-04-20': {'1. open': '25.0700', '2. high': '25.2900', '3. low': '24.8400', '4. close': '25.2500', '5. volume': '18808644'}, '2022-04-19': {'1. open': '25.0300', '2. high': '25.4000', '3. low': '24.7900', '4. close': '25.0100', '5. volume': '16104061'}, '2022-04-18': {'1. open': '25.5200', '2. high': '25.9900', '3. low': '25.3600', '4. close': '25.3800', '5. volume': '15103652'}
# ...
